# %%
import numpy as np
import pandas as pd
import combat as cb

# %%
#df = pd.read_csv('rankMatrix.txt', sep='\t')

# %%
#df.head()

# %%
#df2 = pd.read_csv('ExprMat_rma.csv')

# %%
#df2.head()

# %%
#df3 =pd.read_csv('cmap/cmap_build02.volume1of7/myAnnot.xls',sep='\t')

# %%
#df3.head(20)

# %%
df1 = pd.read_csv('cmap_build02.volume1of7/614615111406/ExprMat_rma_614615111406.csv', sep=',')

# %%
df1.head()
# Out:
#   Unnamed: 0  614615111406.A01.CEL  614615111406.A02.CEL  \
# 0  1007_s_at              6.306076              6.552163
# 1    1053_at              7.199347              7.200777
# 2     117_at              5.376993              5.403883
# 3     121_at              7.263090              7.436624
# 4  1255_g_at              3.309611              3.221523
#
#    614615111406.A03.CEL  614615111406.A04.CEL  614615111406.A05.CEL  \
# 0              6.422616              6.571218              6.670610
# 1              7.345029              6.723921              7.058716
# 2              5.425258              5.412750              5.326335
# 3              7.401567              7.118254              7.544809
# 4              3.439271              3.405418              3.417316
#
#    614615111406.A06.CEL  614615111406.A07.CEL  614615111406.A08.CEL  \
# 0              6.690657              6.158504              6.378969
# 1              7.193071              7.224932              7.241373
# ...

# %%
df1.shape
# Out:
# (22283, 92)

# %%
df2 = pd.read_csv('cmap_build02.volume1of7/622623112706/ExprMat_rma_622623112706.csv', sep=',')

# %%
df2.head()
# Out:
#   Unnamed: 0  622623112706.A01.CEL  622623112706.A02.CEL  \
# 0  1007_s_at              6.299123              6.220120
# 1    1053_at              6.645112              6.615556
# 2     117_at              5.284134              5.391690
# 3     121_at              7.086426              7.184301
# 4  1255_g_at              3.137714              3.151583
#
#    622623112706.A03.CEL  622623112706.A05.CEL  622623112706.A06.CEL  \
# 0              6.307102              6.115693              6.240061
# 1              6.665117              6.657200              6.612730
# 2              5.320264              5.202388              5.193766
# 3              6.678852              7.098543              7.153736
# 4              3.153269              3.163815              3.306579
#
#    622623112706.A12.CEL  622623112706.B01.CEL  622623112706.B02.CEL  \
# 0              6.355163              6.297932              6.159785
# 1              6.858298              6.808376              6.753302
# ...

# %%
df2.shape
# Out:
# (22283, 58)

# %%
df3 = pd.read_csv('cmap_build02.volume1of7/5202764005789148112904/ExprMat_rma_5202764005789148112904.csv', sep=',')

# %%
df3.head()
# Out:
#   Unnamed: 0  5202764005789148112904.A01.CEL  5202764005789148112904.A02.CEL  \
# 0  1007_s_at                       11.042811                       10.792239
# 1    1053_at                        9.385190                        9.454614
# 2     117_at                        5.719272                        5.862642
# 3     121_at                        6.439006                        6.604952
# 4  1255_g_at                        5.198969                        5.193489
#
#    5202764005789148112904.A03.CEL  5202764005789148112904.A04.CEL  \
# 0                       10.953898                       10.933075
# 1                        9.205553                        9.498066
# 2                        6.122223                        6.052822
# 3                        6.680459                        6.653906
# 4                        5.155168                        5.213094
#
#    5202764005789148112904.A05.CEL  5202764005789148112904.A06.CEL  \
# ...

# %%
df3.shape
# Out:
# (22944, 221)

# %%
df4 = pd.read_csv('cmap_build02.volume1of7/5500024017802120306174/ExprMat_rma_5500024017802120306174.csv', sep=',')

# %%
df5 = pd.read_csv('cmap_build02.volume1of7/CL2004060801/ExprMat_rma_CL2004060801.csv', sep=',')

# %%
df6 = pd.read_csv('cmap_build02.volume1of7/EC2003090/ExprMat_rma_EC2003090.csv', sep=',')

# %%
df_1of7 = pd.merge(df1,df2, how='outer', on='Unnamed: 0')

# %%
df_1of7 = pd.merge(df_1of7,df3, how='outer', on='Unnamed: 0')
df_1of7 = pd.merge(df_1of7,df4, how='outer', on='Unnamed: 0')
df_1of7 = pd.merge(df_1of7,df5, how='outer', on='Unnamed: 0')
df_1of7 = pd.merge(df_1of7,df6, how='outer', on='Unnamed: 0')

# %%
df_1of7.head()
# Out:
#   Unnamed: 0  614615111406.A01.CEL  614615111406.A02.CEL  \
# 0  1007_s_at              6.306076              6.552163
# 1    1053_at              7.199347              7.200777
# 2     117_at              5.376993              5.403883
# 3     121_at              7.263090              7.436624
# 4  1255_g_at              3.309611              3.221523
#
#    614615111406.A03.CEL  614615111406.A04.CEL  614615111406.A05.CEL  \
# 0              6.422616              6.571218              6.670610
# 1              7.345029              6.723921              7.058716
# 2              5.425258              5.412750              5.326335
# 3              7.401567              7.118254              7.544809
# 4              3.439271              3.405418              3.417316
#
#    614615111406.A06.CEL  614615111406.A07.CEL  614615111406.A08.CEL  \
# 0              6.690657              6.158504              6.378969
# 1              7.193071              7.224932              7.241373
# ...

# %%
df_1of7.shape
# Out:
# (22959, 1000)

# %%
df_1of7.dropna(how='all', inplace=True)

# %%
df_1of7.shape
# Out:
# (22959, 1000)

# %%
df_1of7.to_csv('1of7.csv', sep=',', index=False)

# %%
df1= pd.read_csv('cmap_build02.volume2of7/55000/ExprMat_rma_55000.csv', sep=',')

# %%
df1.shape
# Out:
# (22277, 688)

# %%
df2= pd.read_csv('cmap_build02.volume2of7/610611110806/ExprMat_rma_610611110806.csv', sep=',')

# %%
df2.shape
# Out:
# (22283, 93)

# %%
df3=pd.read_csv('cmap_build02.volume2of7/612613111306/ExprMat_rma_612613111306.csv', sep=',')

# %%
df3.shape
# Out:
# (22283, 97)

# %%
df4=pd.read_csv('cmap_build02.volume2of7/622623112706/ExprMat_rma_622623112706.csv', sep=',')

# %%
df4.shape
# Out:
# (22283, 35)

# %%
df5=pd.read_csv('cmap_build02.volume2of7/640641112706/ExprMat_rma_640641112706.csv', sep=',')

# %%
df5.shape
# Out:
# (22283, 92)

# %%
df_2of7 = pd.merge(df1,df2, how='outer', on='Unnamed: 0')

# %%
df_2of7 = pd.merge(df_2of7,df3, how='outer', on='Unnamed: 0')
df_2of7 = pd.merge(df_2of7,df4, how='outer', on='Unnamed: 0')
df_2of7 = pd.merge(df_2of7,df5, how='outer', on='Unnamed: 0')

# %%
df_2of7.head()
# Out:
#   Unnamed: 0  5500024024213121906558.A01.CEL  5500024024213121906558.A02.CEL  \
# 0  1007_s_at                       10.669355                       10.346496
# 1    1053_at                        8.592836                        8.396591
# 2     117_at                        4.473752                        4.482585
# 3     121_at                        7.052179                        7.103314
# 4  1255_g_at                        4.157902                        4.124172
#
#    5500024024213121906558.A03.CEL  5500024024213121906558.A04.CEL  \
# 0                       10.593716                       10.652184
# 1                        8.421771                        8.435450
# 2                        4.371718                        4.350173
# 3                        6.936423                        6.957646
# 4                        4.146273                        4.157075
#
#    5500024024213121906558.A05.CEL  5500024024213121906558.A06.CEL  \
# ...

# %%
df_2of7.dropna(how='all', inplace=True)

# %%
df_2of7.to_csv('2of7.csv', sep=',', index=False)

# %%
df_3of7 = pd.read_csv('cmap_build02.volume3of7/ExprMat_rma.csv', sep=',')

# %%
df_3of7.dropna(how='all', inplace=True)

# %%
df_3of7.to_csv('3of7.csv', sep=',', index=False)

# %%
df_4of7=pd.read_csv('cmap_build02.volume4of7/ExprMat_rma.csv', sep=',')

# %%
df_4of7.dropna(how='all', inplace=True)

# %%
df_4of7.to_csv('4of7.csv', sep=',', index=False)

# %%
df_5of7=pd.read_csv('cmap_build02.volume5of7/ExprMat_rma.csv', sep=',')

# %%
df_5of7.dropna(how='all', inplace=True)

# %%
df_5of7.to_csv('5of7.csv', sep=',', index=False)

# %%
df_6of7=pd.read_csv('cmap_build02.volume6of7/ExprMat_rma.csv', sep=',')

# %%
df_6of7.dropna(how='all', inplace=True)

# %%
df_6of7.to_csv('6of7.csv', sep=',', index=False)

# %%
df_7of7=pd.read_csv('cmap_build02.volume7of7/ExprMat_rma.csv', sep=',')

# %%
df_7of7.dropna(how='all', inplace=True)

# %%
df_7of7.to_csv('7of7.csv', sep=',', index=False)

# %%
df = pd.merge(df_1of7,df_2of7, how='outer', on='Unnamed: 0')

# %%
df = pd.merge(df,df_3of7, how='outer', on='Unnamed: 0')
df = pd.merge(df,df_4of7, how='outer', on='Unnamed: 0')
df = pd.merge(df,df_5of7, how='outer', on='Unnamed: 0')
df = pd.merge(df,df_6of7, how='outer', on='Unnamed: 0')
df = pd.merge(df,df_7of7, how='outer', on='Unnamed: 0')

# %%
df.shape
# Out:
# (22959, 7039)

# %%
df.head()
# Out:
#   Unnamed: 0  614615111406.A01.CEL  614615111406.A02.CEL  \
# 0  1007_s_at              6.306076              6.552163
# 1    1053_at              7.199347              7.200777
# 2     117_at              5.376993              5.403883
# 3     121_at              7.263090              7.436624
# 4  1255_g_at              3.309611              3.221523
#
#    614615111406.A03.CEL  614615111406.A04.CEL  614615111406.A05.CEL  \
# 0              6.422616              6.571218              6.670610
# 1              7.345029              6.723921              7.058716
# 2              5.425258              5.412750              5.326335
# 3              7.401567              7.118254              7.544809
# 4              3.439271              3.405418              3.417316
#
#    614615111406.A06.CEL  614615111406.A07.CEL  614615111406.A08.CEL  \
# 0              6.690657              6.158504              6.378969
# 1              7.193071              7.224932              7.241373
# ...

# %%
df.to_csv('cmap_merged.csv', sep=',', index=False)

# %%
df = pd.read_csv('cmap_merged.csv', sep=',')

# %%
lst = []
lst.append('Unnamed: 0')
for col in df.columns:
    if col != 'Unnamed: 0':
        lst.append(col.split('.')[0]+'.'+col.split('.')[1])
df.columns = lst

# %%
df.set_index('Unnamed: 0', inplace=True)

# %%
df.head()
# Out:
#             614615111406.A01  614615111406.A02  614615111406.A03  \
# Unnamed: 0
# 1007_s_at           6.306076          6.552163          6.422616
# 1053_at             7.199347          7.200777          7.345029
# 117_at              5.376993          5.403883          5.425258
# 121_at              7.263090          7.436624          7.401567
# 1255_g_at           3.309611          3.221523          3.439271
#
#             614615111406.A04  614615111406.A05  614615111406.A06  \
# Unnamed: 0
# 1007_s_at           6.571218          6.670610          6.690657
# 1053_at             6.723921          7.058716          7.193071
# 117_at              5.412750          5.326335          5.267829
# 121_at              7.118254          7.544809          7.518370
# 1255_g_at           3.405418          3.417316          3.364671
#
#             614615111406.A07  614615111406.A08  614615111406.A09  \
# Unnamed: 0
# 1007_s_at           6.158504          6.378969          6.547272
# ...

# %%
#lst

# %%
meta = pd.read_excel('cmap_instances_02.xlsx')

# %%
meta.head()
# Out:
#   instance_id batch_id   cmap_name INN1  concentration (M)  duration (h)  \
# 0           1        1   metformin  INN       1.000000e-05           6.0
# 1           2        1   metformin  INN       1.000000e-05           6.0
# 2           3        1   metformin  INN       1.000000e-07           6.0
# 3           4        1   metformin  INN       1.000000e-03           6.0
# 4          21        2  phenformin  INN       1.000000e-05           6.0
#
#   cell2    array3 perturbation_scan_id vehicle_scan_id4               scanner  \
# 0  MCF7  HG-U133A       EC2003090503AA   EC2003090502AA  HP GeneArray Scanner
# 1  MCF7  HG-U133A       EC2003090504AA   EC2003090502AA  HP GeneArray Scanner
# 2  MCF7  HG-U133A       EC2003090505AA   EC2003090502AA  HP GeneArray Scanner
# 3  MCF7  HG-U133A       EC2003090506AA   EC2003090502AA  HP GeneArray Scanner
# 4  MCF7  HG-U133A       EC2003091104AA   EC2003091102AA  HP GeneArray Scanner
#
# ...

# %%
meta.shape
# Out:
# (6109, 15)

# %%
meta.set_index('perturbation_scan_id', inplace=True)

# %%
in_both = meta.index.intersection(df_for_cambat.columns)

# %%
df_for_cambat = df_for_cambat[in_both]

# %%
df.to_csv('cmap_merged_for_combat.txt', sep='\t', index=False)

# %%
meta = meta.ix[df_for_cambat.columns]

# %%
meta.shape
# Out:
# (5121, 14)

# %%
df.shape
# Out:
# (22959, 5121)

# %%
meta_for_combat = pd.DataFrame(columns=['Array name', 'Sample name', 'Batch'])

# %%
meta_for_combat['Array name'] = meta.index
meta_for_combat['Sample name'] = meta.index
meta_for_combat['Batch'] = meta['batch_id'].values

# %%
meta_for_combat.shape
# Out:
# (5121, 3)

# %%
meta_for_combat.head()
# Out:
#          Array name       Sample name Batch
# 0  614615111406.A01  614615111406.A01   614
# 1  614615111406.A02  614615111406.A02   614
# 2  614615111406.A03  614615111406.A03   614
# 3  614615111406.A04  614615111406.A04   614
# 4  614615111406.A05  614615111406.A05   614

# %%
meta_for_combat.to_csv('meta_for_combat.txt', sep='\t', index=False)

# %%
meta.head()
# Out:
#                      instance_id batch_id        cmap_name INN1  \
# perturbation_scan_id
# 614615111406.A01            1399      614        isoniazid  INN
# 614615111406.A02            1400      614   trichostatin A  NaN
# 614615111406.A03            1401      614  tranexamic acid  INN
# 614615111406.A04            1402      614         ampyrone  NaN
# 614615111406.A05            1403      614        midodrine  INN
#
#                       concentration (M)  duration (h) cell2    array3  \
# perturbation_scan_id
# 614615111406.A01           2.920000e-05           6.0  HL60  HG-U133A
# 614615111406.A02           1.000000e-07           6.0  HL60  HG-U133A
# 614615111406.A03           2.540000e-05           6.0  HL60  HG-U133A
# 614615111406.A04           1.960000e-05           6.0  HL60  HG-U133A
# 614615111406.A05           1.380000e-05           6.0  HL60  HG-U133A
#
#                               vehicle_scan_id4 scanner vehicle  \
# perturbation_scan_id
# ...

# %%
batch_c_df = cb.combat(df.values, meta['batch_id'])
# Out:
# /Users/moshesilverstein/Desktop/cmap/combat.py:79: FutureWarning: iterkv is deprecated and will be removed in a future release, use ``iteritems`` instead.
#   drop_cols = [cname for cname, inter in  ((model == 1).all()).iterkv() if inter == True]
# found 215 batches
# found 0 numerical covariates...
# found 0 categorical variables:
# Standardizing Data across genes.
# /Users/moshesilverstein/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   a = empty(shape, dtype, order)
# Fitting L/S model and finding priors
# /Users/moshesilverstein/Desktop/cmap/combat.py:107: VisibleDeprecationWarning: non integer (and non boolean) array-likes will not be accepted as indices in the future
#   delta_hat.append(s_data[batch_idxs].var(axis=1))
# ---------------------------------------------------------------------------
# ...

# %%
meta['batch_id'] =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-39fad9bfae81> in <module>()
# ----> 1 meta['batch_id'] = int(meta['batch_id'].values)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
batch_c_df.head(10)
# Out:
#             614615111406.A01  614615111406.A02  614615111406.A03  \
# Unnamed: 0
# 1007_s_at                NaN               NaN               NaN
# 1053_at                  NaN               NaN               NaN
# 117_at                   NaN               NaN               NaN
# 121_at                   NaN               NaN               NaN
# 1255_g_at                NaN               NaN               NaN
# 1294_at                  NaN               NaN               NaN
# 1316_at                  NaN               NaN               NaN
# 1320_at                  NaN               NaN               NaN
# 1405_i_at                NaN               NaN               NaN
# 1431_at                  NaN               NaN               NaN
#
#             614615111406.A04  614615111406.A05  614615111406.A07  \
# Unnamed: 0
# 1007_s_at                NaN               NaN               NaN
# 1053_at                  NaN               NaN               NaN
# ...

# %%
#len(meta['batch_id'].unique())

# %%
df_for_cambat = pd.read_csv('cmap_merged_for_combat.csv', sep='\t')

# %%
df_for_cambat.head()
# Out:
#    614615111406.A01  614615111406.A02  614615111406.A03  614615111406.A04  \
# 0          6.306076          6.552163          6.422616          6.571218
# 1          7.199347          7.200777          7.345029          6.723921
# 2          5.376993          5.403883          5.425258          5.412750
# 3          7.263090          7.436624          7.401567          7.118254
# 4          3.309611          3.221523          3.439271          3.405418
#
#    614615111406.A05  614615111406.A07  614615111406.A08  614615111406.A09  \
# 0          6.670610          6.158504          6.378969          6.547272
# 1          7.058716          7.224932          7.241373          7.176339
# 2          5.326335          5.323736          5.386450          5.320827
# 3          7.544809          7.190336          7.211324          7.442084
# 4          3.417316          3.186808          3.493382          3.259353
#
#    614615111406.A10  614615111406.A11             ...              \
# ...

# %%
df_for_cambat.shape
# Out:
# (22959, 5121)

# %%
df_for_cambat.dropna(how='any', inplace=True)

# %%
df_for_cambat.shape
# Out:
# (22268, 5121)

# %%
df_for_cambat.head()
# Out:
#    614615111406.A01  614615111406.A02  614615111406.A03  614615111406.A04  \
# 0          6.306076          6.552163          6.422616          6.571218
# 1          7.199347          7.200777          7.345029          6.723921
# 2          5.376993          5.403883          5.425258          5.412750
# 3          7.263090          7.436624          7.401567          7.118254
# 4          3.309611          3.221523          3.439271          3.405418
#
#    614615111406.A05  614615111406.A07  614615111406.A08  614615111406.A09  \
# 0          6.670610          6.158504          6.378969          6.547272
# 1          7.058716          7.224932          7.241373          7.176339
# 2          5.326335          5.323736          5.386450          5.320827
# 3          7.544809          7.190336          7.211324          7.442084
# 4          3.417316          3.186808          3.493382          3.259353
#
#    614615111406.A10  614615111406.A11             ...              \
# ...

# %%
df_for_cambat.columns[5120] == meta_for_combat['Array name'][5120]
# Out:
# True

# %%
meta_for_combat.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-7dba4f2cc1e3> in <module>()
# ----> 1 meta_for_combat.shape
#
# NameError: name 'meta_for_combat' is not defined

# %%
lst = []
for a in meta_for_combat['Batch']:
    a = int(a)
    lst.append(a)
meta_for_combat['Batch'] = lst

# %%
batch_c_df = cb.combat(df_for_cambat, meta_for_combat['Batch'])
# Out:
# /Users/moshesilverstein/Desktop/cmap/combat.py:79: FutureWarning: iterkv is deprecated and will be removed in a future release, use ``iteritems`` instead.
#   drop_cols = [cname for cname, inter in  ((model == 1).all()).iterkv() if inter == True]
# found 215 batches
# found 0 numerical covariates...
# found 0 categorical variables:
# Standardizing Data across genes.
# /Users/moshesilverstein/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py:190: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   a = empty(shape, dtype, order)
# Fitting L/S model and finding priors
# Finding parametric adjustments
# /Users/moshesilverstein/Desktop/cmap/combat.py:158: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   sum2 = ((sdat - np.dot(g_new.reshape((g_new.shape[0], 1)), np.ones((1, sdat.shape[1])))) ** 2).sum(axis=1)
# Adjusting data

# %%
batch_c_df.head()
# Out:
#    614615111406.A01  614615111406.A02  614615111406.A03  614615111406.A04  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    614615111406.A05  614615111406.A07  614615111406.A08  614615111406.A09  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
#
#    614615111406.A10  614615111406.A11             ...              \
# ...

# %%
batch_c_df.shape
# Out:
# (22959, 5121)

# %%
#rank_df = pd.read_csv('rankMatrix.txt', sep='\t')

# %%
#rank_df.head()
# Out:
#     probe_id      1      2      3      4     21     22     23     61    121  \
# 0  1007_s_at   6432  12201   5085   7854   2100   4118   5129   3003   5414
# 1    1053_at   4817  15753  17671   6825  14301  19613   4922   5466   1837
# 2     117_at  21798  17152  21366  21892   7585    728   1923  10639   1974
# 3     121_at   3435   1669   2628   4541   2834   4562  16875   5107  19426
# 4  1255_g_at   7647   2382   4808  13994  13436   8442  13401  12433  11159
#
#        ...         7551   7552   7553   7554   7555   7556   7557   7558  \
# 0      ...         6422   6363   8174   8215  18915   7063   6620  17845
# 1      ...        19964   6165   6225   6731   2641   1801    752   1108
# 2      ...        11529  12283  14820  14093  12097  12033  12947   8753
# 3      ...        19828  21102   9260  10601  18445   2854  20629  17235
# 4      ...        14608  13048  15238  15535  12493  10398  13352  11639
#
#     7559  Unnamed: 6101
# 0   4489            NaN
# ...

# %%
#rank_df.shape
# Out:
# (22283, 6102)

# %%
probes_to_genes = pd.read_csv('Probes2Genes.csv', sep=',')

# %%
probes_to_genes.head()
# Out:
#    Unnamed: 0    PROBEID   SYMBOL
# 0           1  1007_s_at     DDR1
# 1           2  1007_s_at  MIR4640
# 2           3    1053_at     RFC2
# 3           4     117_at    HSPA6
# 4           5     121_at     PAX8

# %%
probes_to_genes.shape
# Out:
# (25190, 3)

# %%
probes_to_genes = probes_to_genes.drop_duplicates(subset='PROBEID', keep=False)

# %%
probes_to_genes.shape
# Out:
# (21684, 3)

# %%
probes_to_genes.set_index('PROBEID', inplace=True)

# %%
probes_to_genes.dropna(inplace=True)

# %%
probes_to_genes.shape
# Out:
# (19861, 2)

# %%
# i = 1
# for index in rank_df.index:
#     index_pub = rank_df.ix[index, 'probe_id']
#     print('\r', str(i)+' Out of '+ str(len(rank_df.index)), end=' ', flush=True)
#     if index_pub in probes_to_genes.index:
#         rank_df.ix[index, 'probe_id'] = probes_to_genes.ix[index_pub, 'SYMBOL']
#     else:
#         rank_df.ix[index, 'probe_id'] = np.nan
#     i += 1
# Out:
#  22283 Out of 22283

# %%
index_pub
# Out:
# '1007_s_at'

# %%
#rank_df.head()
# Out:
#   probe_id      1      2      3      4     21     22     23     61    121  \
# 0      NaN   6432  12201   5085   7854   2100   4118   5129   3003   5414
# 1     RFC2   4817  15753  17671   6825  14301  19613   4922   5466   1837
# 2    HSPA6  21798  17152  21366  21892   7585    728   1923  10639   1974
# 3     PAX8   3435   1669   2628   4541   2834   4562  16875   5107  19426
# 4   GUCA1A   7647   2382   4808  13994  13436   8442  13401  12433  11159
#
#        ...         7551   7552   7553   7554   7555   7556   7557   7558  \
# 0      ...         6422   6363   8174   8215  18915   7063   6620  17845
# 1      ...        19964   6165   6225   6731   2641   1801    752   1108
# 2      ...        11529  12283  14820  14093  12097  12033  12947   8753
# 3      ...        19828  21102   9260  10601  18445   2854  20629  17235
# 4      ...        14608  13048  15238  15535  12493  10398  13352  11639
#
#     7559  Unnamed: 6101
# 0   4489            NaN
# 1    873            NaN
# ...

# %%
#up = pd.read_csv('msigdb_gene_sets/msigdb_up_mapped_to_HG_U133A.gmt', header=None)

# %%
#up.head()

# %%
# build up library

up = pd.read_csv('msigdb_gene_sets/msigdb_up_mapped_to_HG_U133A.gmt', header=None)

i = 1

lib_up = pd.DataFrame()

for index in up.index:
    lst = []
    print('\r', str(i)+' Out of '+ str(len(up.index)), end=' ', flush=True)
    
    lst.append('_'.join(up.ix[index, 0].split('\t')[0].split('_'))[0:-3])
    
    genes = up.ix[index, 0].split('\t')[2:]
    
    for gene in genes:
        if gene in probes_to_genes.index and probes_to_genes.ix[gene, 'SYMBOL'] != 'NaN':
            lst.append(probes_to_genes.ix[gene, 'SYMBOL'])

    temp = pd.DataFrame(data=lst)
    lib_up = pd.concat([lib_up, temp.T])
    i += 1

lib_up.replace(np.nan, ' ', inplace=True)

lib_up.to_csv('cmap_up.gmt', sep='\t', header=None, index=False)
# Out:
#  312 Out of 312

# %%
# build up library

down = pd.read_csv('msigdb_gene_sets/msigdb_dn_mapped_to_HG_U133A.gmt', header=None)

i = 1

lib_down = pd.DataFrame()

for index in down.index:
    lst = []
    print('\r', str(i)+' Out of '+ str(len(down.index)), end=' ', flush=True)
    
    lst.append('_'.join(down.ix[index, 0].split('\t')[0].split('_'))[0:-3])
    
    genes = down.ix[index, 0].split('\t')[2:]
    
    for gene in genes:
        if gene in probes_to_genes.index and probes_to_genes.ix[gene, 'SYMBOL'] != 'NaN':
            lst.append(probes_to_genes.ix[gene, 'SYMBOL'])

    temp = pd.DataFrame(data=lst)
    lib_down = pd.concat([lib_down, temp.T])
    i += 1

lib_down.replace(np.nan, ' ', inplace=True)

lib_down.to_csv('cmap_down.gmt', sep='\t', header=None, index=False)
# Out:
#  312 Out of 312

# %%
lib_up.head()
# Out:
#                         0        1        2        3       4      5     \
# 0             PENG_GLUTAMINE     NFIX     GNB3  SLC30A9   TOP2A  PQBP1
# 0  CMV_HCMV_TIMECOURSE_10HRS     FOSB    EFNB2     SFPQ    SFPQ  EFNB2
# 0     MOREAUX_TACI_HI_VS_LOW  HNRNPDL  CACNA1I      MBP  ADAM11  ULBP1
# 0       HDACI_COLON_BUT16HRS     PDP1    FUCA1     SAT1  RHBDF1    CLU
# 0                 AS3_HEK293     MT1X    HMOX1     UAP1  DNAJB1   MT1G
#
#      6       7       8        9    ...  2753 2754 2755 2756 2757 2758 2759  \
# 0  PMAIP1   CAMK1  PLXNB2    CIRBP ...
# 0   RBBP6   RBBP6   RSRP1   RSL1D1 ...
# 0   TACR1   RPL18  RNASE1     BEX1 ...
# 0     CLU    MT1G    MT1H     FLNB ...
# 0   FOSL1  DNAJB1    MT1H  SLC30A1 ...
#
#   2760 2761 2762
# 0
# 0
# 0
# 0
# 0
#
# [5 rows x 2763 columns]

# %%
lib_down.head()
# Out:
#                         0       1       2        3      4        5       6     \
# 0             PENG_GLUTAMINE   FDFT1  HNRNPL     IDH1  GSPT1  SLC29A1   LAMB3
# 0  CMV_HCMV_TIMECOURSE_10HRS   PLIN2    TLE4  STARD13    XPC    KLHL9    TLE4
# 0     MOREAUX_TACI_HI_VS_LOW   UPF3A   EDRF1  SMARCA4  C1QBP    KRIT1  PAPOLA
# 0       HDACI_COLON_BUT16HRS   ABCA1   HMGB1   NUCKS1   DARS     FDPS  NAP1L1
# 0                 AS3_HEK293  PTPN11     MYC   INSIG1   JAK1    WNT5A   TFAP4
#
#     7        8       9    ...  1873 1874 1875 1876 1877 1878 1879 1880 1881  \
# 0   TFRC     AMD1  SNRPA1 ...
# 0  KIF11   PEX11B    TPM2 ...
# 0    RAN     DARS    ILF3 ...
# 0  SNTB1  CAMK2N1    DLG5 ...
# 0  CENPE   PTPN11     TPR ...
#
#   1882
# 0
# 0
# 0
# 0
# 0
#
# [5 rows x 1883 columns]

# %%
#down.head()
